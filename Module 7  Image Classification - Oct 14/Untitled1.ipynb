# %%
import pickle

# Specify the full file path
file_path = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7 Image Classification - Oct 14\history.pkl"


# Load the file using pickle
with open(file_path, 'rb') as file:
    persistedHistory = pickle.load(file)

# Print the contents of the loaded history
print(persistedHistory)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 8
#       4 file_path = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7 Image Classification - Oct 14\history.pkl"
#       7 # Load the file using pickle
# ----> 8 with open(file_path, 'rb') as file:
#       9     persistedHistory = pickle.load(file)
#      11 # Print the contents of the loaded history
#
# File ~\anaconda3\envs\myenv\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# ...

# %%
pip list | findstr tensorflow
# Out:
# tensorflow                    2.10.0
# tensorflow-estimator          2.10.0
# tensorflow-io-gcs-filesystem  0.31.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import load_model

# Load the model
model = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7  Image Classification - Oct 14\TransferModel_InceptionResNetV2.keras"


# Print the model configuration
print("Model Configuration: ", model.get_config())

# Print TensorFlow and Keras versions
import tensorflow as tf
print("TensorFlow Version: ", tf.__version__)
print("Keras Version: ", tf.keras.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tensorflow.keras.models import load_model
#       3 # Load the model
#       4 model = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7  Image Classification - Oct 14\TransferModel_InceptionResNetV2.keras"
#
# File ~\anaconda3\lib\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ...

# %%
pip upgrade pip
pip install tensorflow
# Out:
#   Cell In[7], line 1
#     pip upgrade pip
#         ^
# SyntaxError: invalid syntax

# %%
pkl_path = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7 Image Classification - Oct 14\history.pkl"
with open(pkl_path, 'rb') as file:
    persistedHistory = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 pkl_path = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7 Image Classification - Oct 14\history.pkl"
# ----> 2 with open(pkl_path, 'rb') as file:
#       3     persistedHistory = pickle.load(file)
#
# File ~\anaconda3\envs\myenv\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# ...

# %%
model_path = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7  Image Classification - Oct 14\TransferModel_InceptionResNetV2.keras"
model = load_model(model_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 model_path = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7  Image Classification - Oct 14\TransferModel_InceptionResNetV2.keras"
# ----> 2 model = load_model(model_path)
#
# NameError: name 'load_model' is not defined

# %%
import os

model_path = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7 Image Classification - Oct 14\TransferModel_InceptionResNetV2.keras"
print("Model file exists:", os.path.exists(model_path))

pkl_path = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7 Image Classification - Oct 14\history.pkl"
print("Pickle file exists:", os.path.exists(pkl_path))
# Out:
# Model file exists: False
# Pickle file exists: False

# %%
directory_path = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7  Image Classification - Oct 14"

if os.path.exists(directory_path):
    print("Directory exists")
    print("Contents of the directory:", os.listdir(directory_path))
else:
    print("Directory does not exist")
# Out:
# Directory exists
# Contents of the directory: ['train-20241006T050635Z-001.zip', 'TransferModel_InceptionResNetV2.keras', 'labels.csv', 'Image_transfer.ipynb', 'Image_pretrained.ipynb', 'test-20241006T171636Z-001.zip', '07 - Image Classification.pptx', '.ipynb_checkpoints', 'elephant.jpg', 'Script_Notes.docx', 'test', 'train', 'history.pkl', 'MNIST_Example.ipynb', 'Untitled.ipynb', 'Image_transfer1.ipynb', 'Untitled1.ipynb', 'test.txt']

# %%
import tensorflow as tf

# Specify the path to your model file
model_path = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7  Image Classification - Oct 14\TransferModel_InceptionResNetV2.keras"

# Load the model
model = tf.keras.models.load_model(model_path)

# Verify the model by printing its summary
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import tensorflow as tf
#       3 # Specify the path to your model file
#       4 model_path = r"H:\My Drive\1.a SCHOOL\1.A) Grad School\6. Fall 2024\MIS 776 1001\Module 7  Image Classification - Oct 14\TransferModel_InceptionResNetV2.keras"
#
# File ~\anaconda3\lib\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ...

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Users\zace5\anaconda3\envs\tf_env\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\zace5\anaconda3\envs\tf_env\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\zace5\anaconda3\envs\tf_env\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
# ...

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.24.4
